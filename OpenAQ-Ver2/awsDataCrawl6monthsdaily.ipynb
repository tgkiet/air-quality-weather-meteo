# %% [markdown]
# # CRAWL DATA AIR QUALITY TỪ CÁC TRẠM Ở WEB OPENAQ, 6 THÁNG LƯU 1 LẦN VÀO FILE CSV

# %% [markdown]
# # CELL 1: Cài đặt và Khởi tạo

# %%
import requests
import pandas as pd
import boto3
import io
import os
import glob
from datetime import datetime, timezone
from botocore import UNSIGNED
from botocore.config import Config

# Load secret from .env
from dotenv import load_dotenv
load_dotenv()  # loads .env in project root

API_KEY = os.getenv("OPENAQ_API_KEY")
if not API_KEY:
    raise RuntimeError("OPENAQ_API_KEY not set in environment (.env missing or not loaded)")

BASE_URL = "https://api.openaq.org/v3"
headers = {"X-API-Key": API_KEY}

print("Cell 1: Các thư viện và biến đã được khởi tạo.")
# Out:
# Cell 1: Các thư viện và biến đã được khởi tạo.

# %%
# CELL 2: Lấy thông tin các trạm quan trắc (Trinh sát)

# 1. Lấy danh sách các trạm trong khu vực Hà Nội
bbox = "105.7,20.9,106.0,21.2" # Bounding box cho Hà Nội
print("Đang lấy thông tin các trạm từ API OpenAQ...")
resp = requests.get(f"{BASE_URL}/locations?bbox={bbox}&limit=1000", headers=headers).json()
locations_in_bbox = resp.get("results", [])

# 2. Tạo một "sổ tay tra cứu" (lookup dictionary) chứa thông tin của các trạm
stations_info = {}
earliest_overall_date = datetime.now(timezone.utc)

if not locations_in_bbox:
    print("Không tìm thấy trạm nào trong khu vực đã chọn.")
else:
    print(f"Tìm thấy {len(locations_in_bbox)} trạm. Bắt đầu xử lý thông tin từng trạm...")
    for loc in locations_in_bbox:
        loc_id = loc['id']
        
        # Xử lý an toàn cho datetimeFirst
        dt_first_obj = loc.get("datetimeFirst")
        if dt_first_obj and dt_first_obj.get("utc"):
            first_dt_str = dt_first_obj["utc"]
            start_date = datetime.fromisoformat(first_dt_str.replace("Z", "+00:00"))
            if start_date < earliest_overall_date:
                earliest_overall_date = start_date
        else:
            print(f"  - Trạm ID {loc_id} ({loc.get('name', 'N/A')}) bị bỏ qua do thiếu thông tin 'datetimeFirst'.")
            continue
            
        # Xử lý an toàn cho datetimeLast
        dt_last_obj = loc.get("datetimeLast")
        if dt_last_obj and dt_last_obj.get("utc"):
            last_dt_str = dt_last_obj["utc"]
            end_date = datetime.fromisoformat(last_dt_str.replace("Z", "+00:00"))
        else:
            end_date = datetime.now(timezone.utc)
            
        stations_info[loc_id] = {
            "name": loc.get('name', 'Unknown'),
            "start_date": start_date,
            "end_date": end_date
        }
    
    print("-" * 20)
    print(f"Cell 2: Đã thu thập thông tin của {len(stations_info)} trạm hợp lệ.")
    if stations_info:
        print(f"Toàn bộ dữ liệu sẽ được quét từ tháng: {earliest_overall_date.strftime('%Y-%m')}")
# Out:
# Đang lấy thông tin các trạm từ API OpenAQ...
# Tìm thấy 33 trạm. Bắt đầu xử lý thông tin từng trạm...
#   - Trạm ID 18 (SPARTAN - Vietnam Acad. Sci.) bị bỏ qua do thiếu thông tin 'datetimeFirst'.
#   - Trạm ID 307169 (nồng độ pm) bị bỏ qua do thiếu thông tin 'datetimeFirst'.
# --------------------
# Cell 2: Đã thu thập thông tin của 31 trạm hợp lệ.
# Toàn bộ dữ liệu sẽ được quét từ tháng: 2016-01

# %%
# CELL 3: Tải dữ liệu và lưu riêng lẻ (Tải hàng loạt)

# Kiểm tra xem các biến từ Cell 2 đã tồn tại chưa
if 'stations_info' not in locals() or not stations_info:
    print("Vui lòng chạy Cell 2 trước để lấy thông tin các trạm.")
else:
    # 1. Tạo thư mục chính
    main_output_dir = "hanoi_air_quality_data_raw"
    if not os.path.exists(main_output_dir):
        os.makedirs(main_output_dir)
        print(f"Đã tạo thư mục chính: {main_output_dir}")

    # 2. Thiết lập kết nối S3
    s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED, region_name='us-east-1'))
    bucket_name = 'openaq-data-archive'
    
    total_files_downloaded = 0
    print(f"Bắt đầu quá trình tải dữ liệu cho {len(stations_info)} trạm...")

    # 3. Lặp qua từng trạm
    for loc_id, info in stations_info.items():
        print(f"\n--- Đang xử lý trạm ID: {loc_id} ({info['name']}) ---")

        station_dir = os.path.join(main_output_dir, str(loc_id))
        if not os.path.exists(station_dir):
            os.makedirs(station_dir)

        # 4. Xác định các năm mà trạm này có dữ liệu
        years_to_scan = range(info['start_date'].year, info['end_date'].year + 1)
        
        for year in years_to_scan:
            # 5. Xử lý thành 2 nửa: Nửa đầu năm (H1) và Nửa cuối năm (H2)
            for semester in [1, 2]:
                months_in_semester = range(1, 7) if semester == 1 else range(7, 13)
                semester_label = "H1" if semester == 1 else "H2"
                
                semester_data_frames = []
                
                for month in months_in_semester:
                    prefix = (f"records/csv.gz/locationid={loc_id}/"
                              f"year={year}/"
                              f"month={month:02d}/")
                    
                    try:
                        paginator = s3.get_paginator('list_objects_v2')
                        pages = paginator.paginate(Bucket=bucket_name, Prefix=prefix)

                        for page in pages:
                            if 'Contents' not in page: continue
                            
                            for obj in page['Contents']:
                                file_key = obj['Key']
                                s3_object = s3.get_object(Bucket=bucket_name, Key=file_key)
                                bytes_buffer = io.BytesIO(s3_object['Body'].read())
                                df = pd.read_csv(bytes_buffer, compression='gzip', header=0)
                                semester_data_frames.append(df)
                                total_files_downloaded += 1
                                print(f"  -> Đã tải file: {file_key.split('/')[-1]} ({len(df)} dòng)")

                    except Exception as e:
                        if 'NoSuchKey' not in str(e) and 'AccessDenied' not in str(e):
                             print(f"    -> Lỗi khi quét {prefix}: {e}")

                # 6. Gộp và lưu file cho cả nửa năm
                if semester_data_frames:
                    semester_df = pd.concat(semester_data_frames, ignore_index=True)
                    semester_df['datetime'] = pd.to_datetime(semester_df['datetime'], utc=True)
                    
                    semester_df = semester_df[semester_df['datetime'].between(info['start_date'], info['end_date'])]

                    if not semester_df.empty:
                        output_filename = os.path.join(station_dir, f"{loc_id}_{year}_{semester_label}.csv")
                        semester_df.to_csv(output_filename, index=False, encoding='utf-8-sig')
                        print(f"  ==> ĐÃ LƯU: {len(semester_df)} dòng dữ liệu cho {semester_label}/{year} vào file {output_filename}")

    print(f"\n---> HOÀN TẤT QUÁ TRÌNH TẢI <---")
    print(f"Cell 3: Tổng cộng đã tải và xử lý {total_files_downloaded} file.")
#
# --- Đang xử lý trạm ID: 4946812 (Công viên hồ điều hòa Nhân Chính, Khuất Duy Tiến) ---
#   -> Đã tải file: location-4946812-20250703.csv.gz (97 dòng)
#   -> Đã tải file: location-4946812-20250704.csv.gz (1230 dòng)
#   -> Đã tải file: location-4946812-20250705.csv.gz (1281 dòng)
#   -> Đã tải file: location-4946812-20250706.csv.gz (1418 dòng)
#   -> Đã tải file: location-4946812-20250707.csv.gz (1383 dòng)
#   -> Đã tải file: location-4946812-20250708.csv.gz (1421 dòng)
#   -> Đã tải file: location-4946812-20250709.csv.gz (1433 dòng)
#   -> Đã tải file: location-4946812-20250710.csv.gz (1499 dòng)
#   -> Đã tải file: location-4946812-20250711.csv.gz (1460 dòng)
#   -> Đã tải file: location-4946812-20250712.csv.gz (1499 dòng)
#   -> Đã tải file: location-4946812-20250713.csv.gz (1350 dòng)
#   -> Đã tải file: location-4946812-20250714.csv.gz (1371 dòng)
#   -> Đã tải file: location-4946812-20250715.csv.gz (1323 dòng)
#   -> Đã tải file: location-4946812-20250716.csv.gz (1232 dòng)
#   -> Đã tải file: location-4946812-20250717.csv.gz (1249 dòng)
#   -> Đã tải file: location-4946812-20250718.csv.gz (1206 dòng)
#   -> Đã tải file: location-4946812-20250719.csv.gz (924 dòng)
#   -> Đã tải file: location-4946812-20250720.csv.gz (1079 dòng)
#   -> Đã tải file: location-4946812-20250721.csv.gz (1307 dòng)
#   -> Đã tải file: location-4946812-20250722.csv.gz (1048 dòng)
#   -> Đã tải file: location-4946812-20250723.csv.gz (1186 dòng)
#   -> Đã tải file: location-4946812-20250724.csv.gz (1417 dòng)
#   -> Đã tải file: location-4946812-20250725.csv.gz (1321 dòng)
#   -> Đã tải file: location-4946812-20250726.csv.gz (1405 dòng)
#   -> Đã tải file: location-4946812-20250727.csv.gz (1067 dòng)
#   -> Đã tải file: location-4946812-20250728.csv.gz (1083 dòng)
#   -> Đã tải file: location-4946812-20250729.csv.gz (1283 dòng)
#   -> Đã tải file: location-4946812-20250730.csv.gz (1430 dòng)
#   -> Đã tải file: location-4946812-20250731.csv.gz (1274 dòng)
#   -> Đã tải file: location-4946812-20250801.csv.gz (1291 dòng)
#   -> Đã tải file: location-4946812-20250802.csv.gz (1313 dòng)
#   -> Đã tải file: location-4946812-20250803.csv.gz (1360 dòng)
#   -> Đã tải file: location-4946812-20250804.csv.gz (1298 dòng)
#   -> Đã tải file: location-4946812-20250805.csv.gz (1372 dòng)
#   -> Đã tải file: location-4946812-20250806.csv.gz (1291 dòng)
#   -> Đã tải file: location-4946812-20250807.csv.gz (1372 dòng)
#   -> Đã tải file: location-4946812-20250808.csv.gz (1144 dòng)
#   -> Đã tải file: location-4946812-20250809.csv.gz (1234 dòng)
#   -> Đã tải file: location-4946812-20250810.csv.gz (990 dòng)
#   -> Đã tải file: location-4946812-20250811.csv.gz (1143 dòng)
#   -> Đã tải file: location-4946812-20250812.csv.gz (1343 dòng)
#   -> Đã tải file: location-4946812-20250813.csv.gz (1460 dòng)
#   -> Đã tải file: location-4946812-20250814.csv.gz (1166 dòng)
#   -> Đã tải file: location-4946812-20250815.csv.gz (1105 dòng)
#   -> Đã tải file: location-4946812-20250816.csv.gz (963 dòng)
#   -> Đã tải file: location-4946812-20250817.csv.gz (1017 dòng)
#   -> Đã tải file: location-4946812-20250818.csv.gz (1061 dòng)
#   -> Đã tải file: location-4946812-20250819.csv.gz (961 dòng)
#   -> Đã tải file: location-4946812-20250820.csv.gz (1314 dòng)
#   -> Đã tải file: location-4946812-20250821.csv.gz (1182 dòng)
#   -> Đã tải file: location-4946812-20250822.csv.gz (1011 dòng)
#   -> Đã tải file: location-4946812-20250823.csv.gz (737 dòng)
#   -> Đã tải file: location-4946812-20250824.csv.gz (490 dòng)
#   -> Đã tải file: location-4946812-20250825.csv.gz (638 dòng)
#   -> Đã tải file: location-4946812-20250826.csv.gz (810 dòng)
#   -> Đã tải file: location-4946812-20250827.csv.gz (815 dòng)
#   -> Đã tải file: location-4946812-20250828.csv.gz (797 dòng)
#   -> Đã tải file: location-4946812-20250829.csv.gz (976 dòng)
#   -> Đã tải file: location-4946812-20250830.csv.gz (925 dòng)
#   -> Đã tải file: location-4946812-20250831.csv.gz (968 dòng)
#   -> Đã tải file: location-4946812-20250901.csv.gz (987 dòng)
#   -> Đã tải file: location-4946812-20250902.csv.gz (1041 dòng)
#   -> Đã tải file: location-4946812-20250903.csv.gz (1013 dòng)
#   -> Đã tải file: location-4946812-20250904.csv.gz (1026 dòng)
#   -> Đã tải file: location-4946812-20250905.csv.gz (1225 dòng)
#   -> Đã tải file: location-4946812-20250906.csv.gz (1225 dòng)
#   -> Đã tải file: location-4946812-20250907.csv.gz (1303 dòng)
#   -> Đã tải file: location-4946812-20250908.csv.gz (1319 dòng)
#   -> Đã tải file: location-4946812-20250909.csv.gz (1360 dòng)
#   -> Đã tải file: location-4946812-20250910.csv.gz (1312 dòng)
#   -> Đã tải file: location-4946812-20250911.csv.gz (1130 dòng)
#   -> Đã tải file: location-4946812-20250912.csv.gz (1144 dòng)
#   -> Đã tải file: location-4946812-20250913.csv.gz (1245 dòng)
#   -> Đã tải file: location-4946812-20250914.csv.gz (1238 dòng)
#   -> Đã tải file: location-4946812-20250915.csv.gz (1197 dòng)
#   -> Đã tải file: location-4946812-20250916.csv.gz (1217 dòng)
#   -> Đã tải file: location-4946812-20250917.csv.gz (1275 dòng)
#   -> Đã tải file: location-4946812-20250918.csv.gz (1300 dòng)
#   -> Đã tải file: location-4946812-20250919.csv.gz (1235 dòng)
#   -> Đã tải file: location-4946812-20250920.csv.gz (1270 dòng)
#   -> Đã tải file: location-4946812-20250921.csv.gz (1262 dòng)
#   -> Đã tải file: location-4946812-20250922.csv.gz (1139 dòng)
#   -> Đã tải file: location-4946812-20250923.csv.gz (1153 dòng)
#   -> Đã tải file: location-4946812-20250924.csv.gz (1008 dòng)
#   -> Đã tải file: location-4946812-20250925.csv.gz (988 dòng)
#   -> Đã tải file: location-4946812-20250926.csv.gz (930 dòng)
#   -> Đã tải file: location-4946812-20250927.csv.gz (1098 dòng)
#   -> Đã tải file: location-4946812-20250928.csv.gz (1048 dòng)
#   ==> ĐÃ LƯU: 102511 dòng dữ liệu cho H2/2025 vào file hanoi_air_quality_data_raw\4946812\4946812_2025_H2.csv
#
# --- Đang xử lý trạm ID: 4946813 (ĐH Bách Khoa - cổng Parabol đường Giải Phóng) ---
#   -> Đã tải file: location-4946813-20250703.csv.gz (87 dòng)
#   -> Đã tải file: location-4946813-20250704.csv.gz (1235 dòng)
#   -> Đã tải file: location-4946813-20250705.csv.gz (1123 dòng)
#   -> Đã tải file: location-4946813-20250706.csv.gz (1263 dòng)
#   -> Đã tải file: location-4946813-20250707.csv.gz (1138 dòng)
#   -> Đã tải file: location-4946813-20250708.csv.gz (1359 dòng)
#   -> Đã tải file: location-4946813-20250709.csv.gz (1310 dòng)
#   -> Đã tải file: location-4946813-20250710.csv.gz (1430 dòng)
#   -> Đã tải file: location-4946813-20250711.csv.gz (1341 dòng)
#   -> Đã tải file: location-4946813-20250712.csv.gz (1398 dòng)
#   -> Đã tải file: location-4946813-20250713.csv.gz (1384 dòng)
#   -> Đã tải file: location-4946813-20250714.csv.gz (1216 dòng)
#   -> Đã tải file: location-4946813-20250715.csv.gz (1238 dòng)
#   -> Đã tải file: location-4946813-20250716.csv.gz (1235 dòng)
#   -> Đã tải file: location-4946813-20250717.csv.gz (1092 dòng)
#   -> Đã tải file: location-4946813-20250718.csv.gz (1235 dòng)
#   -> Đã tải file: location-4946813-20250719.csv.gz (847 dòng)
#   -> Đã tải file: location-4946813-20250720.csv.gz (1065 dòng)
#   -> Đã tải file: location-4946813-20250721.csv.gz (1244 dòng)
#   -> Đã tải file: location-4946813-20250722.csv.gz (1088 dòng)
#   -> Đã tải file: location-4946813-20250723.csv.gz (1166 dòng)
#   -> Đã tải file: location-4946813-20250724.csv.gz (1352 dòng)
#   -> Đã tải file: location-4946813-20250725.csv.gz (1329 dòng)
#   -> Đã tải file: location-4946813-20250726.csv.gz (1371 dòng)
#   -> Đã tải file: location-4946813-20250727.csv.gz (1106 dòng)
#   -> Đã tải file: location-4946813-20250728.csv.gz (1067 dòng)
#   -> Đã tải file: location-4946813-20250729.csv.gz (1176 dòng)
#   -> Đã tải file: location-4946813-20250730.csv.gz (1185 dòng)
#   -> Đã tải file: location-4946813-20250731.csv.gz (1121 dòng)
#   -> Đã tải file: location-4946813-20250801.csv.gz (1176 dòng)
#   -> Đã tải file: location-4946813-20250802.csv.gz (1338 dòng)
#   -> Đã tải file: location-4946813-20250803.csv.gz (1349 dòng)
#   -> Đã tải file: location-4946813-20250804.csv.gz (1175 dòng)
#   -> Đã tải file: location-4946813-20250805.csv.gz (1272 dòng)
#   -> Đã tải file: location-4946813-20250806.csv.gz (1241 dòng)
#   -> Đã tải file: location-4946813-20250807.csv.gz (1339 dòng)
#   -> Đã tải file: location-4946813-20250808.csv.gz (1061 dòng)
#   -> Đã tải file: location-4946813-20250809.csv.gz (1187 dòng)
#   -> Đã tải file: location-4946813-20250810.csv.gz (911 dòng)
#   -> Đã tải file: location-4946813-20250811.csv.gz (1034 dòng)
#   -> Đã tải file: location-4946813-20250812.csv.gz (1083 dòng)
#   -> Đã tải file: location-4946813-20250813.csv.gz (1162 dòng)
#   -> Đã tải file: location-4946813-20250814.csv.gz (998 dòng)
#   -> Đã tải file: location-4946813-20250815.csv.gz (960 dòng)
#   -> Đã tải file: location-4946813-20250816.csv.gz (731 dòng)
#   -> Đã tải file: location-4946813-20250817.csv.gz (830 dòng)
#   -> Đã tải file: location-4946813-20250818.csv.gz (762 dòng)
#   -> Đã tải file: location-4946813-20250819.csv.gz (796 dòng)
#   -> Đã tải file: location-4946813-20250820.csv.gz (1105 dòng)
#   -> Đã tải file: location-4946813-20250821.csv.gz (992 dòng)
#   -> Đã tải file: location-4946813-20250822.csv.gz (823 dòng)
#   -> Đã tải file: location-4946813-20250823.csv.gz (694 dòng)
#   -> Đã tải file: location-4946813-20250824.csv.gz (573 dòng)
#   -> Đã tải file: location-4946813-20250825.csv.gz (434 dòng)
#   -> Đã tải file: location-4946813-20250826.csv.gz (437 dòng)
#   -> Đã tải file: location-4946813-20250827.csv.gz (70 dòng)
#   -> Đã tải file: location-4946813-20250828.csv.gz (293 dòng)
#   -> Đã tải file: location-4946813-20250829.csv.gz (645 dòng)
#   -> Đã tải file: location-4946813-20250830.csv.gz (692 dòng)
#   -> Đã tải file: location-4946813-20250831.csv.gz (750 dòng)
#   -> Đã tải file: location-4946813-20250901.csv.gz (652 dòng)
#   -> Đã tải file: location-4946813-20250902.csv.gz (401 dòng)
#   -> Đã tải file: location-4946813-20250903.csv.gz (751 dòng)
#   -> Đã tải file: location-4946813-20250904.csv.gz (1368 dòng)
#   -> Đã tải file: location-4946813-20250905.csv.gz (1478 dòng)
#   -> Đã tải file: location-4946813-20250906.csv.gz (1495 dòng)
#   -> Đã tải file: location-4946813-20250907.csv.gz (1532 dòng)
#   -> Đã tải file: location-4946813-20250908.csv.gz (1511 dòng)
#   -> Đã tải file: location-4946813-20250909.csv.gz (1098 dòng)
#   -> Đã tải file: location-4946813-20250910.csv.gz (1333 dòng)
#   -> Đã tải file: location-4946813-20250911.csv.gz (1239 dòng)
#   -> Đã tải file: location-4946813-20250912.csv.gz (1269 dòng)
#   -> Đã tải file: location-4946813-20250913.csv.gz (1356 dòng)
#   -> Đã tải file: location-4946813-20250914.csv.gz (1146 dòng)
#   -> Đã tải file: location-4946813-20250915.csv.gz (1070 dòng)
#   -> Đã tải file: location-4946813-20250916.csv.gz (1096 dòng)
#   -> Đã tải file: location-4946813-20250917.csv.gz (1198 dòng)
#   -> Đã tải file: location-4946813-20250918.csv.gz (1378 dòng)
#   -> Đã tải file: location-4946813-20250919.csv.gz (1279 dòng)
#   -> Đã tải file: location-4946813-20250920.csv.gz (1431 dòng)
#   -> Đã tải file: location-4946813-20250921.csv.gz (1473 dòng)
#   -> Đã tải file: location-4946813-20250922.csv.gz (1407 dòng)
#   -> Đã tải file: location-4946813-20250923.csv.gz (1202 dòng)
#   -> Đã tải file: location-4946813-20250924.csv.gz (1238 dòng)
#   -> Đã tải file: location-4946813-20250925.csv.gz (1083 dòng)
#   -> Đã tải file: location-4946813-20250926.csv.gz (1000 dòng)
#   -> Đã tải file: location-4946813-20250927.csv.gz (1204 dòng)
#   -> Đã tải file: location-4946813-20250928.csv.gz (1208 dòng)
#   ==> ĐÃ LƯU: 96010 dòng dữ liệu cho H2/2025 vào file hanoi_air_quality_data_raw\4946813\4946813_2025_H2.csv
#
# ---> HOÀN TẤT QUÁ TRÌNH TẢI <---
# Cell 3: Tổng cộng đã tải và xử lý 6722 file.
# Dữ liệu đã được lưu vào các thư mục con trong 'hanoi_air_quality_data_raw'

# %%
# CELL 4: Gộp các file dữ liệu (Tổng hợp)

main_output_dir = "hanoi_air_quality_data_raw"

if not os.path.exists(main_output_dir):
    print(f"Thư mục '{main_output_dir}' không tồn tại. Vui lòng chạy Cell 3 trước.")
else:
    all_csv_files = glob.glob(os.path.join(main_output_dir, '**', '*.csv'), recursive=True)
    
    if not all_csv_files:
        print("Không tìm thấy file CSV nào để gộp.")
    else:
        print(f"Tìm thấy {len(all_csv_files)} file CSV. Bắt đầu gộp...")
        
        all_data_frames = [pd.read_csv(f) for f in all_csv_files]
        final_df_long = pd.concat(all_data_frames, ignore_index=True)
        
        final_df_long['datetime'] = pd.to_datetime(final_df_long['datetime'])
        final_df_long = final_df_long.sort_values(by=['location_id', 'datetime'])
        
        final_output_filename = "hanoi_air_quality_history_COMBINED_LONG.csv"
        final_df_long.to_csv(final_output_filename, index=False, encoding='utf-8-sig')
        
        print("\n---> QUÁ TRÌNH GỘP HOÀN TẤT <---")
        print(f"Cell 4: Dữ liệu dạng dài đã được gộp và lưu vào file '{final_output_filename}'")
# Out:
# Tìm thấy 70 file CSV. Bắt đầu gộp...
#
# ---> QUÁ TRÌNH GỘP HOÀN TẤT <---
# Cell 4: Dữ liệu dạng dài đã được gộp và lưu vào file 'hanoi_air_quality_history_COMBINED_LONG.csv'

# %%
# CELL 5 (Cập nhật): Làm sạch và Biến đổi

import pandas as pd
import numpy as np # Thêm thư viện numpy để sử dụng np.nan
import os

long_format_file = "hanoi_air_quality_history_COMBINED_LONG.csv"

if not os.path.exists(long_format_file):
    print(f"File '{long_format_file}' không tồn tại. Vui lòng chạy Cell 4 trước.")
else:
    print(f"Đang đọc file '{long_format_file}'...")
    df_long = pd.read_csv(long_format_file)
    print(f"Đã đọc xong. Tổng số dòng ban đầu: {len(df_long)}")

    # --- BƯỚC 1: LÀM SẠCH DỮ LIỆU ---
    print("\nBắt đầu quá trình làm sạch dữ liệu...")
    # Đếm số lượng giá trị không hợp lệ trước khi xử lý
    invalid_values_count = (df_long['value'] < 0).sum()
    print(f"Tìm thấy {invalid_values_count} dòng có giá trị 'value' âm (bao gồm -999).")

    # Thay thế tất cả các giá trị 'value' âm bằng NaN
    # Điều này sẽ xử lý cả -999.0 và các giá trị âm khác nếu có
    df_long['value'] = df_long['value'].apply(lambda x: np.nan if x < 0 else x)
    print("Đã thay thế các giá trị không hợp lệ bằng NaN.")
    
    # Bỏ các dòng không còn giá trị 'value' nào (đã bị thay thế bằng NaN)
    df_long.dropna(subset=['value'], inplace=True)
    print(f"Tổng số dòng còn lại sau khi loại bỏ các giá trị không hợp lệ: {len(df_long)}")
    # ------------------------------------

    print("\nBắt đầu chuyển đổi sang dạng rộng...")
    # Loại bỏ các cột không cần thiết trước khi pivot
    columns_to_pivot = ['location_id', 'datetime', 'parameter', 'value']
    df_wide = df_long[columns_to_pivot].pivot_table(
        index=['location_id', 'datetime'], 
        columns='parameter', 
        values='value'
    ).reset_index()
    
    wide_output_filename = "hanoi_air_quality_history_COMBINED_WIDE_CLEANED.csv"
    df_wide.to_csv(wide_output_filename, index=False, encoding='utf-8-sig')
    
    print("\n---> QUÁ TRÌNH BIẾN ĐỔI HOÀN TẤT <---")
    print(f"Cell 5: Dữ liệu đã được làm sạch, chuyển đổi và lưu vào file '{wide_output_filename}'")
    print("\nXem trước 15 dòng đầu của dữ liệu dạng rộng đã được làm sạch:")
    print(df_wide.head(15))
# Out:
# Đang đọc file 'hanoi_air_quality_history_COMBINED_LONG.csv'...
# Đã đọc xong. Tổng số dòng ban đầu: 663848
#
# Bắt đầu quá trình làm sạch dữ liệu...
# Tìm thấy 10650 dòng có giá trị 'value' âm (bao gồm -999).
# Đã thay thế các giá trị không hợp lệ bằng NaN.
# Tổng số dòng còn lại sau khi loại bỏ các giá trị không hợp lệ: 653198
#
# Bắt đầu chuyển đổi sang dạng rộng...
#
# ---> QUÁ TRÌNH BIẾN ĐỔI HOÀN TẤT <---
# Cell 5: Dữ liệu đã được làm sạch, chuyển đổi và lưu vào file 'hanoi_air_quality_history_COMBINED_WIDE_CLEANED.csv'
#
# Xem trước 15 dòng đầu của dữ liệu dạng rộng đã được làm sạch:
# parameter  location_id                   datetime  co  no2  o3  pm10  pm25  \
# 0                 2539  2016-01-30 01:00:00+00:00 NaN  NaN NaN   NaN  42.0
# 1                 2539  2016-01-30 02:00:00+00:00 NaN  NaN NaN   NaN  42.2
# 2                 2539  2016-01-30 03:00:00+00:00 NaN  NaN NaN   NaN  48.7
# 3                 2539  2016-01-30 04:00:00+00:00 NaN  NaN NaN   NaN  41.6
# 4                 2539  2016-01-30 05:00:00+00:00 NaN  NaN NaN   NaN  30.8
# 5                 2539  2016-01-30 06:00:00+00:00 NaN  NaN NaN   NaN  24.8
# 6                 2539  2016-01-30 13:00:00+00:00 NaN  NaN NaN   NaN  55.1
# 7                 2539  2016-01-30 14:00:00+00:00 NaN  NaN NaN   NaN  58.1
# 8                 2539  2016-01-30 15:00:00+00:00 NaN  NaN NaN   NaN  61.8
# 9                 2539  2016-01-30 16:00:00+00:00 NaN  NaN NaN   NaN  57.3
# 10                2539  2016-01-30 17:00:00+00:00 NaN  NaN NaN   NaN  68.1
# 11                2539  2016-01-30 20:00:00+00:00 NaN  NaN NaN   NaN  53.4
# 12                2539  2016-01-30 21:00:00+00:00 NaN  NaN NaN   NaN  35.9
# 13                2539  2016-01-31 05:00:00+00:00 NaN  NaN NaN   NaN  39.1
# 14                2539  2016-01-31 06:00:00+00:00 NaN  NaN NaN   NaN  44.2
#
# parameter  so2
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
